# %% [markdown]
# ## Retrieval Augmented Generation
#
# this is just a simple notebook for me to learn RAG
#
# You can also learn it here : https://www.deeplearning.ai/courses/retrieval-augmented-generation

# %% [markdown]
# ### 1 - List

# %%
# Example of a list

l1 = ['RAG', 'is', 'Awesome']
print(f"Original List : {l1}")

# Adding an item
l1.append("!")
print(f"List after adding '!' : {l1}")

# Removing an item
l1.remove('Awesome')
print(f"List after removing 'Awesome' : {l1}")

result = l1.append("this is a test")
print(result)
# Out:
# Original List : ['RAG', 'is', 'Awesome']
# List after adding '!' : ['RAG', 'is', 'Awesome', '!']
# List after removing 'Awesome' : ['RAG', 'is', '!']
# None

# %% [markdown]
# ### 1.2 List Comperhensions

# %%
# An example of list comperhension to create a list of squares
squares = [x**2 for x in range(10)  ]
print(f"Squares of numbers from 0 to 9: {squares} (with list comprehension)")

# The same example using for loop
squares_for_loop = []
for x in range(10):
    squares_for_loop.append(x**2)
print(f"Squares of numbers from 0 to 9: {squares_for_loop} (without list comprehension)")
# Out:
# Squares of numbers from 0 to 9: [0, 1, 4, 9, 16, 25, 36, 49, 64, 81] (with list comprehension)
# Squares of numbers from 0 to 9: [0, 1, 4, 9, 16, 25, 36, 49, 64, 81] (without list comprehension)

# %%
# Conditional List Comperhension
even_squares = [x**2 for x in range(10) if x % 2 == 0]
print(f"Squares of even numbers from 0 to 9: {even_squares} (with list comprehension)")

squares_for_loop = []
for x in range(10) :
    if x % 2 == 0 :
        squares_for_loop.append(x**2)
print(f"Squares of numbers from 0 to 9: {squares_for_loop} (without list comprehension)")
# Out:
# Squares of even numbers from 0 to 9: [0, 4, 16, 36, 64] (with list comprehension)
# Squares of numbers from 0 to 9: [0, 4, 16, 36, 64] (without list comprehension)

# %% [markdown]
# ## 2 - Dictionaries

# %% [markdown]
# ### 2.1 Introductions

# %%
# Example of a dictionary
person = {
    'name': 'Fathir Rizki Fadillah',
    'age': 19,
    'city': 'Bekasi'
}
print(f"Person dictionary: {person}")

# Accessing a value
print(f"Name: {person['name']}")

# Adding a new key-value pair
person['email'] = 'fathir@example.com'
print(f"Updated person dictionary: {person}")
# Out:
# Person dictionary: {'name': 'Fathir Rizki Fadillah', 'age': 19, 'city': 'Bekasi'}
# Name: Fathir Rizki Fadillah
# Updated person dictionary: {'name': 'Fathir Rizki Fadillah', 'age': 19, 'city': 'Bekasi', 'email': 'fathir@example.com'}

# %% [markdown]
# ### 2.2 Method `.items`

# %%
for key, value in person.items():
    print(f"Key: {key}\tValue: {value}")
# Out:
# Key: name	Value: Fathir Rizki Fadillah
# Key: age	Value: 19
# Key: city	Value: Bekasi
# Key: email	Value: fathir@example.com

# %%
for val in person:
    print(val)
# Out:
# name
# age
# city
# email

# %% [markdown]
# ## 3 - f-string

# %% [markdown]
# ### 3.1

# %%
# Basic f-string example
name = 'Fathir'
age = 19
greeting = f"Hello, My name is {name}. I'm {age} years old"
print(greeting)
# Out:
# Hello, My name is Fathir. I'm 19 years old

# %% [markdown]
# ### 3.2 F-string in Action

# %%
people = [
    {
        "name": "Alice Johnson",
        "age": 28,
        "email": "alice.johnson@example.com",
        "location": "New York, NY"
    },
    {
        "name": "Michael Smith",
        "age": 34,
        "email": "michael.smith@example.com",
        "location": "Los Angeles, CA"
    },
    {
        "name": "Emily Davis",
        "age": 22,
        "email": "emily.davis@example.com",
        "location": "Austin, TX"
    },
    {
        "name": "John Brown",
        "age": 45,
        "email": "john.brown@example.com",
        "location": "Chicago, IL"
    },
    {
        "name": "Sarah Wilson",
        "age": 31,
        "email": "sarah.wilson@example.com",
        "location": "Seattle, WA"
    }
]

# %%
# First, create an empty list to store the sentences:
t = []
# Iterate over the list of dictionary
for person_info_dict in people:
    # person_info_dict is a dict and you can access its values using the keys
    layout_string = f"Name: {person_info_dict['name']}, Age: {person_info_dict['age']}, E-mail: {person_info_dict['email']}, Location: {person_info_dict['location']}"
    # Append the string with the desired information into the list
    t.append(layout_string) # Add a new line character at the end
# Create the result layout by using the .join method
# The .join function concatenates every string in the list 't', separated by the specified delimiter. Here, each element of 't' is joined using the newline character '\n'.print(formatted_string)
formatted_string = "\n".join(t) 
print(formatted_string)
# Out:
# Name: Alice Johnson, Age: 28, E-mail: alice.johnson@example.com, Location: New York, NY
# Name: Michael Smith, Age: 34, E-mail: michael.smith@example.com, Location: Los Angeles, CA
# Name: Emily Davis, Age: 22, E-mail: emily.davis@example.com, Location: Austin, TX
# Name: John Brown, Age: 45, E-mail: john.brown@example.com, Location: Chicago, IL
# Name: Sarah Wilson, Age: 31, E-mail: sarah.wilson@example.com, Location: Seattle, WA

# %%
# Another way of creating strings that depend on parameters is the following:
template = "Name: {name}, Age: {age}, E-mail: {email}, Location: {location}"
t = []
for person_info_dict in people:
    # person_info_dict is a dict and you can access its values using the keys
    # Append the string with a new information using the .format method
    layout_string = template.format(name = person_info_dict['name'], 
                         age = person_info_dict['age'], 
                         email = person_info_dict['email'], 
                         location = person_info_dict['location'])
    t.append(layout_string)
formatted_string = "\n".join(t)
print(formatted_string)
# Out:
# Name: Alice Johnson, Age: 28, E-mail: alice.johnson@example.com, Location: New York, NY
# Name: Michael Smith, Age: 34, E-mail: michael.smith@example.com, Location: Los Angeles, CA
# Name: Emily Davis, Age: 22, E-mail: emily.davis@example.com, Location: Austin, TX
# Name: John Brown, Age: 45, E-mail: john.brown@example.com, Location: Chicago, IL
# Name: Sarah Wilson, Age: 31, E-mail: sarah.wilson@example.com, Location: Seattle, WA

# %% [markdown]
# # LLM Calls and Crafting Simple Augmented Prompts

# %%
from dotenv import load_dotenv
load_dotenv()

from utils import (
    generate_with_single_input, 
    generate_with_multiple_input,
    get_proxy_url,
    get_proxy_headers,
    get_groq_key
)

# %% [markdown]
# ## 1 - Understanding the functions to call LLMs

# %% [markdown]
# ### 1.1 `generate_with_single_input`

# %%
# Example call
output = generate_with_single_input(
    prompt="What is the capital of France?"
)

print("Role:", output['role'])
print("Content:", output['content'])
# Out:
# Role: assistant
# Content: The capital of France is **Paris**.

# %% [markdown]
# ### 1.2 `generate_with_multiple_input`

# %%
# Example call
messages = [
    {'role': 'user', 'content': 'Hello, who won the FIFA world cup in 2018?'},
    {'role': 'assistant', 'content': 'France won the 2018 FIFA World Cup.'},
    {'role': 'user', 'content': 'Who was the captain?'}
]

output = generate_with_multiple_input(
    messages=messages,
    max_tokens=100
)

print("Role:", output['role'])
print("Content:", output['content'])
# Out:
# Role: assistant
# Content: The captain of France’s 2018 World Cup‑winning team was **Hugo Lloris**, the goalkeeper who led the squad throughout the tournament.

# %% [markdown]
# ### 1.3 Integration with OpenAI library

# %%
from openai import OpenAI, DefaultHttpxClient
import httpx

# %%
base_url = get_proxy_url() # If using together endpoint, add it here https://api.together.xyz/

# Custom transport to bypass SSL verification. This is only needed if using our proxy. Otherwise you can ignore it.
transport = httpx.HTTPTransport(local_address="0.0.0.0", verify=False)

# Create a DefaultHttpxClient instance with the custom transport
http_client = DefaultHttpxClient(transport=transport, headers=get_proxy_headers())

client = OpenAI(
    api_key = get_groq_key(), # Set any as our proxy does not use it. Set the together api key if using the together endpoint.
    base_url=base_url, 
    http_client=http_client, # ssl bypass to make it work via proxy calls, remove it if running with together.ai endpoint 
)

# %%
response = client.chat.completions.create(
    messages = messages, 
    model = "openai/gpt-oss-120b"
)

# %%
print(response.choices[0].message.content)
# Out:
# The captain of the French national team during the 2018 FIFA World Cup was **Hugo Lloris**, the team's goalkeeper and long‑time leader.

# %% [markdown]
# ## 2 - Integrating Data into an LLM Prompt

# %% [markdown]
# ### 2.1 Understanding the data structure

# %%
house_data = [
    {
        "address": "123 Maple Street",
        "city": "Springfield",
        "state": "IL",
        "zip": "62701",
        "bedrooms": 3,
        "bathrooms": 2,
        "square_feet": 1500,
        "price": 230000,
        "year_built": 1998
    },
    {
        "address": "456 Elm Avenue",
        "city": "Shelbyville",
        "state": "TN",
        "zip": "37160",
        "bedrooms": 4,
        "bathrooms": 3,
        "square_feet": 2500,
        "price": 320000,
        "year_built": 2005
    }
]

# %% [markdown]
# ### 2.2 Creating the prompt

# %%
# First, let's create a layout for the houses

def house_info_layout(houses):
    # Create an empty string
    layout = ''
    # Iterate over the houses
    for house in houses:
        # For each house, append the information to the string using f-strings
        # The following way using brackets is a good way to make the code readable as in each line you can start a new f-string that will appended to the previous one
        layout += (f"House located at {house['address']}, {house['city']}, {house['state']} {house['zip']} with "
            f"{house['bedrooms']} bedrooms, {house['bathrooms']} bathrooms, "
            f"{house['square_feet']} sq ft area, priced at ${house['price']}, "
            f"built in {house['year_built']}.\n") # Don't forget the new line character at the end!
    return layout

# %%
# Check the layout
print(house_info_layout(house_data))
# Out:
# House located at 123 Maple Street, Springfield, IL 62701 with 3 bedrooms, 2 bathrooms, 1500 sq ft area, priced at $230000, built in 1998.
# House located at 456 Elm Avenue, Shelbyville, TN 37160 with 4 bedrooms, 3 bathrooms, 2500 sq ft area, priced at $320000, built in 2005.

# %%
def generate_prompt(query, houses):
    # The code made above is modular enough to accept any list of houses, so you could also choose a subset of the dataset.
    # This might be useful in a more complex context where you want to give only some information to the LLM and not the entire data
    houses_layout = house_info_layout(houses)
    # Create a hard-coded prompt. You can use three double quotes (") in this cases, so you don't need to worry too much about using single or double quotes and breaking the code
    PROMPT = f"""
Use the following houses information to answer users queries.
{houses_layout}
Query: {query}    
             """
    return PROMPT

# %%
print(generate_prompt("What is the most expensive house?", houses = house_data))
# Out:
# Use the following houses information to answer users queries.
# House located at 123 Maple Street, Springfield, IL 62701 with 3 bedrooms, 2 bathrooms, 1500 sq ft area, priced at $230000, built in 1998.
# House located at 456 Elm Avenue, Shelbyville, TN 37160 with 4 bedrooms, 3 bathrooms, 2500 sq ft area, priced at $320000, built in 2005.
#
# Query: What is the most expensive house?

# %%
query = "What is the most expensive house? And the bigger one?"
# Asking without the augmented prompt, let's pass the role as user
query_without_house_info = generate_with_single_input(prompt = query, role = 'user')
# With house info, given the prompt structuer, let's pass the role as assistant
enhanced_query = generate_prompt(query, houses = house_data)
query_with_house_info = generate_with_single_input(prompt = enhanced_query, role = 'assistant')

# %%
# Without house info
print(query_without_house_info['content'])
# Out:
# Below is a snapshot (as of 2026) of the two “super‑houses” that usually top every list:
#
# | Rank | Name of Residence | Location | Owner (as of 2026) | Approx. Value* | Size (floor‑area) | Key Highlights |
# |------|-------------------|----------|--------------------|----------------|-------------------|----------------|
# | **Most expensive private home** | **Antilia** | South Mumbai, India | Mukesh Ambani (Reliance Industries) | **US $2 – 3 billion** (est.) | ~400,000 sq ft (≈37,000 sq m) of usable space (≈27 floors) | • 27 stories, 3 underground parking levels<br>• 6 helicopter pads, 2 spas, a 9‑car garage, a 150‑seat theater, a multi‑level garden, a ballroom, a temple, and a 30‑person

# %%
# With house info
print(query_with_house_info['content'])
# Out:
# **Most expensive house:**
# - **Address:** 456 Elm Avenue, Shelbyville, TN 37160
# - **Price:** **$320,000**
#
# **Bigger house (by square footage):**
# - **Address:** 456 Elm Avenue, Shelbyville, TN 37160
# - **Living area:** **2,500 sq ft**
#
# So the house on **456 Elm Avenue** is both the most expensive and the larger of the two properties.
